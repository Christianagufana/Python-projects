# %%
Name = input('Enter your name:').title()
print('Hello am a small assistant,what is your name?.')
print(f'Hello {Name},nice to meet you!')
Action =input('Choose what to do (Play,study,listen to music, sleep,eat:').lower()

if Action == 'play':
    print('Okay loading game.....')
elif Action == 'study':
    print('Okay picking topics to study.')
elif Action == 'listen to music':
    print('Here we go dancing 🕺💃' )
elif Action == 'sleep':
    print(f'{Name} is Snoozing')
elif Action == 'eat':
    print('It is chow time!')
else :
    print(f'Sorry {Name} am still learning, pick another action.')
